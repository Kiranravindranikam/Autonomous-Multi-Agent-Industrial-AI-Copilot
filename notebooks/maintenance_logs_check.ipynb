# %%
import pandas as pd

df = pd.read_csv(
    "../data/raw/maintenance_logs/maintenance_logs.csv"
)

print(df.shape)

df.head()
# Out:
# (1000, 7)
#          date machine_id                issue       action_taken  \
# 0  2023-08-27      M-128        Motor Failure   Replaced Bearing
# 1  2025-03-28      M-134         Rotor Damage    Changed Coolant
# 2  2023-11-22      M-119         Sensor Fault    Changed Coolant
# 3  2024-06-06      M-139  Lubrication Failure  Rotor Replacement
# 4  2024-12-29      M-129        Motor Failure  Rotor Replacement
#
#    downtime_hours  repair_cost technician
# 0           10.36        11645     Tech_D
# 1            4.33         7283     Tech_C
# 2           11.82        19680     Tech_D
# 3            6.07        21367     Tech_E
# 4            9.79        13547     Tech_C
